# %%
# %pip install yfinance
# %pip install matplotlib
# %matplotlib inline

# %%
import yfinance as yfinance

# %%
data = yfinance.Ticker("AAPL").history("6mo")
cierre = data["Close"]
cierre.plot()
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# cotizacion MAX Y MIN Y MID

# %%
max = round(cierre.max(),2)
min = round(cierre.min(),2)
mid = round(cierre.mean(),2)

# %% [markdown]
# # Enviar correo electrónico
#
# ## Pasos
# - Abrir una pestaña del navegador
# - Entrar al correo electrónico
# - Hacer clic en el botón **Redactar**
# - Introducir la dirección de destino
# - Escribir el **asunto**
# - Redactar el mensaje
# - Enviar el correo

# %%
# %pip install pyautogui
# %pip install pyperclip
# Out:
# ...
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# ...
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import pyautogui
import pyperclip
import webbrowser
import time

# %%
webbrowser.open("https://mail.google.com/mail/u/0/#inbox")

time.sleep(3)

pyautogui.click()

# %%
time.sleep(3)
pyautogui.PAUSE =3

pyautogui.position()

destinatario = "correo destino"
asunto = """mcuerpo de asunto """

cuerpo ="""cuerpo de el correo"""
# Out:
# Point(x=960, y=540)
